# %% [markdown]
# ### Learning Pandas:Part II Data Cleaning and Preparation

# %% [markdown]
# In this section we will first load a  csv file using pandas and look after different aspects of loading a csv file.
# After that we will proceed to data cleaning and prepartion.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv('test01.csv')# Data loading from file path
data.head()
# Out:
#   Device Name             Date Temperature (DegC) Unnamed: 3  \
# 0         NaN              NaN               CHWR       CHWS
# 1       BTU-1  2/17/2017 23:55               21.8      18.69
# 2       BTU-2  2/17/2017 23:55              23.35      18.79
# 3       BTU-1  2/17/2017 23:50              22.83      19.57
# 4       BTU-2  2/17/2017 23:50              23.32      19.45
#
#   Flow Rate (USGPM)    TR
# 0              Flow  Load
# 1                96    22
# 2              86.1    29
# 3              93.5  22.5
# 4              81.5  23.2

# %%
data
# Out:
#     Device Name             Date Temperature (DegC) Unnamed: 3  \
# 0           NaN              NaN               CHWR       CHWS
# 1         BTU-1  2/17/2017 23:55               21.8      18.69
# 2         BTU-2  2/17/2017 23:55              23.35      18.79
# 3         BTU-1  2/17/2017 23:50              22.83      19.57
# 4         BTU-2  2/17/2017 23:50              23.32      19.45
# ..          ...              ...                ...        ...
# 570       BTU-2   2/17/2017 0:10              22.64      18.75
# 571       BTU-1   2/17/2017 0:05               22.1      18.79
# 572       BTU-2   2/17/2017 0:05              22.62      18.79
# 573       BTU-1   2/17/2017 0:00              21.97      18.79
# 574       BTU-2   2/17/2017 0:00               22.7      18.73
#
#     Flow Rate (USGPM)    TR
# 0                Flow  Load
# 1                  96    22
# 2                86.1    29
# 3                93.5  22.5
# 4                81.5  23.2
# ..                ...   ...
# ...

# %%
data
# Out:
#     Device Name             Date Temperature (DegC) Unnamed: 3  \
# 0           NaN              NaN               CHWR       CHWS
# 1         BTU-1  2/17/2017 23:55               21.8      18.69
# 2         BTU-2  2/17/2017 23:55              23.35      18.79
# 3         BTU-1  2/17/2017 23:50              22.83      19.57
# 4         BTU-2  2/17/2017 23:50              23.32      19.45
# ..          ...              ...                ...        ...
# 570       BTU-2   2/17/2017 0:10              22.64      18.75
# 571       BTU-1   2/17/2017 0:05               22.1      18.79
# 572       BTU-2   2/17/2017 0:05              22.62      18.79
# 573       BTU-1   2/17/2017 0:00              21.97      18.79
# 574       BTU-2   2/17/2017 0:00               22.7      18.73
#
#     Flow Rate (USGPM)    TR
# 0                Flow  Load
# 1                  96    22
# 2                86.1    29
# 3                93.5  22.5
# 4                81.5  23.2
# ..                ...   ...
# ...

# %%
data.head()
# Out:
#   Device Name             Date Temperature (DegC) Unnamed: 3  \
# 0         NaN              NaN               CHWR       CHWS
# 1       BTU-1  2/17/2017 23:55               21.8      18.69
# 2       BTU-2  2/17/2017 23:55              23.35      18.79
# 3       BTU-1  2/17/2017 23:50              22.83      19.57
# 4       BTU-2  2/17/2017 23:50              23.32      19.45
#
#   Flow Rate (USGPM)    TR
# 0              Flow  Load
# 1                96    22
# 2              86.1    29
# 3              93.5  22.5
# 4              81.5  23.2

# %%
#data.groupby('Device Name')['TR'].aggregate(lambda x: x.sum() / len(x)).plot(kind='bar')

# %% [markdown]
# # iloc
#
# takes integer slices based on index position .iloc needs Integers.

# %%
data.iloc[2:5,2:]
# Out:
#   Temperature (DegC) Unnamed: 3 Flow Rate (USGPM)    TR
# 2              23.35      18.79              86.1    29
# 3              22.83      19.57              93.5  22.5
# 4              23.32      19.45              81.5  23.2

# %%
data.info() # Also Check data.info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 575 entries, 0 to 574
# Data columns (total 6 columns):
# Device Name           574 non-null object
# Date                  574 non-null object
# Temperature (DegC)    575 non-null object
# Unnamed: 3            575 non-null object
# Flow Rate (USGPM)     575 non-null object
# TR                    575 non-null object
# dtypes: object(6)
# memory usage: 27.1+ KB

# %%
data.dtypes # Result shows that all the columns values are object types
# Out:
# Device Name           object
# Date                  object
# Temperature (DegC)    object
# Unnamed: 3            object
# Flow Rate (USGPM)     object
# TR                    object
# dtype: object

# %%
data.tail(3)
# Out:
#     Device Name            Date Temperature (DegC) Unnamed: 3  \
# 572       BTU-2  2/17/2017 0:05              22.62      18.79
# 573       BTU-1  2/17/2017 0:00              21.97      18.79
# 574       BTU-2  2/17/2017 0:00               22.7      18.73
#
#     Flow Rate (USGPM)    TR
# 572              95.7    27
# 573             111.2    26
# 574              94.9  27.8

# %% [markdown]
# .head() and .tail() only gives first or last few entries value,for viewing all rows :>

# %%
pd.set_option('display.max_rows',600)
# This the way we can visualize all the rows to get the idea of values 

data
# Out:
#     Device Name             Date Temperature (DegC) Unnamed: 3  \
# 0           NaN              NaN               CHWR       CHWS
# 1         BTU-1  2/17/2017 23:55               21.8      18.69
# 2         BTU-2  2/17/2017 23:55              23.35      18.79
# 3         BTU-1  2/17/2017 23:50              22.83      19.57
# 4         BTU-2  2/17/2017 23:50              23.32      19.45
# 5         BTU-1  2/17/2017 23:45              22.79       19.4
# 6         BTU-2  2/17/2017 23:45              22.97      19.39
# 7         BTU-1  2/17/2017 23:40              21.51      19.45
# 8         BTU-2  2/17/2017 23:40               22.5      19.51
# 9         BTU-1  2/17/2017 23:35              22.54      19.04
# 10        BTU-2  2/17/2017 23:35              23.43      18.69
# 11        BTU-1  2/17/2017 23:30              22.74      19.45
# 12        BTU-2  2/17/2017 23:30              23.45       19.6
# 13        BTU-1  2/17/2017 23:25               22.6      19.77
# ...

# %% [markdown]
# We can see that there are some '--' entries which have to be  removed or filled with some logical values.

# %%
data[data['Temperature (DegC)']=='--'] #Checking in the 'Temperature (DegC)' column for '--'
# OR : data[data.iloc[:,2]=='--']
# Out:
#     Device Name             Date Temperature (DegC) Unnamed: 3  \
# 24        BTU-2  2/17/2017 23:00                 --      19.66
# 120       BTU-1  2/17/2017 18:55                 --         --
# 121       BTU-2  2/17/2017 18:55                 --         --
# 157       BTU-1  2/17/2017 17:20                 --         --
# 158       BTU-2  2/17/2017 17:20                 --         --
# 183       BTU-1  2/17/2017 16:15                 --         --
# 184       BTU-2  2/17/2017 16:15                 --         --
# 197       BTU-1  2/17/2017 15:40                 --         --
# 198       BTU-2  2/17/2017 15:40                 --         --
#
#     Flow Rate (USGPM)  TR
# 24               82.4  21
# 120                --  --
# 121                --  --
# 157                --  --
# 158                --  --
# 183                --  --
# 184                --  --
# 197                --  --
# 198                --  --

# %%
data[data.iloc[:,2]=='--']
# Out:
#     Device Name             Date Temperature (DegC) Unnamed: 3  \
# 24        BTU-2  2/17/2017 23:00                 --      19.66
# 120       BTU-1  2/17/2017 18:55                 --         --
# 121       BTU-2  2/17/2017 18:55                 --         --
# 157       BTU-1  2/17/2017 17:20                 --         --
# 158       BTU-2  2/17/2017 17:20                 --         --
# 183       BTU-1  2/17/2017 16:15                 --         --
# 184       BTU-2  2/17/2017 16:15                 --         --
# 197       BTU-1  2/17/2017 15:40                 --         --
# 198       BTU-2  2/17/2017 15:40                 --         --
#
#     Flow Rate (USGPM)  TR
# 24               82.4  21
# 120                --  --
# 121                --  --
# 157                --  --
# 158                --  --
# 183                --  --
# 184                --  --
# 197                --  --
# 198                --  --

# %%
data[data['Unnamed: 3']=='--'] # checking in this column for '--'
# OR : data[data.iloc[:,3]=='--']
# Out:
#     Device Name             Date Temperature (DegC) Unnamed: 3  \
# 120       BTU-1  2/17/2017 18:55                 --         --
# 121       BTU-2  2/17/2017 18:55                 --         --
# 157       BTU-1  2/17/2017 17:20                 --         --
# 158       BTU-2  2/17/2017 17:20                 --         --
# 183       BTU-1  2/17/2017 16:15                 --         --
# 184       BTU-2  2/17/2017 16:15                 --         --
# 197       BTU-1  2/17/2017 15:40                 --         --
# 198       BTU-2  2/17/2017 15:40                 --         --
#
#     Flow Rate (USGPM)  TR
# 120                --  --
# 121                --  --
# 157                --  --
# 158                --  --
# 183                --  --
# 184                --  --
# 197                --  --
# 198                --  --

# %%
data[data['Flow Rate (USGPM)']=='--'] # checking in this column for '--'
# OR : > data[data.iloc[:,4]=='--']
# Out:
#     Device Name             Date Temperature (DegC) Unnamed: 3  \
# 11        BTU-1  2/17/2017 23:30              22.74      19.45
# 120       BTU-1  2/17/2017 18:55                 --         --
# 121       BTU-2  2/17/2017 18:55                 --         --
# 157       BTU-1  2/17/2017 17:20                 --         --
# 158       BTU-2  2/17/2017 17:20                 --         --
# 183       BTU-1  2/17/2017 16:15                 --         --
# 184       BTU-2  2/17/2017 16:15                 --         --
# 197       BTU-1  2/17/2017 15:40                 --         --
# 198       BTU-2  2/17/2017 15:40                 --         --
#
#     Flow Rate (USGPM)    TR
# 11                 --  22.9
# 120                --    --
# 121                --    --
# 157                --    --
# 158                --    --
# 183                --    --
# 184                --    --
# 197                --    --
# 198                --    --

# %%
data[data['TR']=='--'] # checking in this column for '--'
# # OR : > data[data.iloc[:,5]=='--']
# Out:
#     Device Name             Date Temperature (DegC) Unnamed: 3  \
# 22        BTU-2  2/17/2017 23:05              23.54      19.61
# 120       BTU-1  2/17/2017 18:55                 --         --
# 121       BTU-2  2/17/2017 18:55                 --         --
# 157       BTU-1  2/17/2017 17:20                 --         --
# 158       BTU-2  2/17/2017 17:20                 --         --
# 183       BTU-1  2/17/2017 16:15                 --         --
# 184       BTU-2  2/17/2017 16:15                 --         --
# 197       BTU-1  2/17/2017 15:40                 --         --
# 198       BTU-2  2/17/2017 15:40                 --         --
#
#     Flow Rate (USGPM)  TR
# 22               82.5  --
# 120                --  --
# 121                --  --
# 157                --  --
# 158                --  --
# 183                --  --
# 184                --  --
# 197                --  --
# 198                --  --

# %%
data[(data['Temperature (DegC)']=='--')|(data['Unnamed: 3']=='--')|(data['Flow Rate (USGPM)']=='--')|\
     (data['TR']=='--')]

# This is a single code using 'or' which gives all the rows with '--'
# Out:
# Empty DataFrame
# Columns: [Device Name, Date, Temperature (DegC), Unnamed: 3, Flow Rate (USGPM), TR]
# Index: []

# %%
#Now we want to replce all the '--'with NaN
a=data[(data['Temperature (DegC)']=='--')|(data['Unnamed: 3']=='--')|\
       (data['Flow Rate (USGPM)']=='--')|(data['TR']=='--')].index
print(a)

# 'a' stores all the index of the rows having '--' .
# Out:
# Int64Index([], dtype='int64')

# %%
data.replace('--',np.nan,inplace=True)

## this will replace all '--' with np.nan

# %%
data.dtypes
# Out:
# Device Name           object
# Date                  object
# Temperature (DegC)    object
# Unnamed: 3            object
# Flow Rate (USGPM)     object
# TR                    object
# dtype: object

# %% [markdown]
# # .loc Label Based Indexing:Take care into account the name or labels of the index when taking slices
#
# syntax: df.loc[row,columns]

# %%
#data.iloc[:,2].mean()
# error, as all the data are string types and arithematic opertaion is not valid for str.
# We have to convert the colums to numeric type( from third to last column)
# Again note that first row can not be converted into numerical data and have to be removed

# %%
data=pd.read_csv('test01.csv')
data1=data.iloc[1:] ## removing zeroth row and taking the remaining slice as data
data1.replace('--',np.nan,inplace=True)
data1
# Out:
# E:\Anaconda\lib\site-packages\pandas\core\frame.py:4263: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,
#     Device Name             Date Temperature (DegC) Unnamed: 3  \
# 1         BTU-1  2/17/2017 23:55               21.8      18.69
# 2         BTU-2  2/17/2017 23:55              23.35      18.79
# 3         BTU-1  2/17/2017 23:50              22.83      19.57
# 4         BTU-2  2/17/2017 23:50              23.32      19.45
# 5         BTU-1  2/17/2017 23:45              22.79       19.4
# 6         BTU-2  2/17/2017 23:45              22.97      19.39
# 7         BTU-1  2/17/2017 23:40              21.51      19.45
# 8         BTU-2  2/17/2017 23:40               22.5      19.51
# 9         BTU-1  2/17/2017 23:35              22.54      19.04
# ...

# %%
for i in range(2,6,1):
    data1.iloc[:,i]= data1.iloc[:,i].astype(float).copy()
    ## Since all columns value conveted to float data

# %%
data1.dtypes 
## Now we see that all our numerical  columns have converted to float and ready for arithematic operations
# Out:
# Device Name            object
# Date                   object
# Temperature (DegC)    float64
# Unnamed: 3            float64
# Flow Rate (USGPM)     float64
# TR                    float64
# dtype: object

# %%
data.groupby('Device Name')['TR'].aggregate(lambda x: x.sum() / len(x)).plot(kind='bar')

# %%
data.groupby('Device Name')['Temperature (DegC)'].aggregate(lambda x: x.sum() / len(x)).plot(kind='bar')

# %%
data.groupby('Device Name')['Flow Rate (USGPM)'].aggregate(lambda x: x.sum() / len(x)).plot(kind='bar')

# %%
data.describe()
# Out:
#        Temperature (DegC)  Unnamed: 3  Flow Rate (USGPM)          TR
# count          565.000000  566.000000         565.000000  565.000000
# mean            22.347522   18.932615         101.822124   25.324956
# std              0.647804    0.493988          12.438191    3.156783
# min             21.000000   17.270000          81.500000    8.100000
# 25%             21.810000   18.490000          94.300000   24.000000
# 50%             22.310000   18.910000          99.300000   25.500000
# 75%             22.810000   19.240000         111.700000   27.000000
# max             23.940000   21.010000         136.000000   40.400000

# %% [markdown]
# ###### Replacing  '--' with nan and changing the specific column dtypes can be done before the data is loaded.
#
# pd.read_csv: It has many other arguments like skiprows, na_values, dtypes as given below :
# This one line of code can reduce lot of pain. We have skip the first row from the original csv file and thus second row will appear as the zeroth row, and thus column name is changed.WOW!!!!

# %%
data2=pd.read_csv(r'test01.csv',skiprows=[0],na_values={'CHWR':['--'],'CHWS':['--'],'Flow':['--'],\
                        'Load':['--']}, dtype={'CHWR':float,'CHWS':float,'Flow':float,'TR':float})
data2.head(100)
# Out:
#    Unnamed: 0       Unnamed: 1   CHWR   CHWS   Flow  Load
# 0       BTU-1  2/17/2017 23:55  21.80  18.69   96.0  22.0
# 1       BTU-2  2/17/2017 23:55  23.35  18.79   86.1  29.0
# 2       BTU-1  2/17/2017 23:50  22.83  19.57   93.5  22.5
# 3       BTU-2  2/17/2017 23:50  23.32  19.45   81.5  23.2
# 4       BTU-1  2/17/2017 23:45  22.79  19.40   98.0  24.5
# 5       BTU-2  2/17/2017 23:45  22.97  19.39   85.3  22.5
# 6       BTU-1  2/17/2017 23:40  21.51  19.45  100.8  15.3
# 7       BTU-2  2/17/2017 23:40  22.50  19.51   86.1  19.0
# 8       BTU-1  2/17/2017 23:35  22.54  19.04  134.5  34.7
# 9       BTU-2  2/17/2017 23:35  23.43  18.69  115.7  40.4
# 10      BTU-1  2/17/2017 23:30  22.74  19.45    NaN  22.9
# 11      BTU-2  2/17/2017 23:30  23.45  19.60   82.8  23.5
# 12      BTU-1  2/17/2017 23:25  22.60  19.77   94.2  19.6
# 13      BTU-2  2/17/2017 23:25  23.07  19.75   82.3  20.1
# 14      BTU-1  2/17/2017 23:20  22.28  18.86   93.8  23.6
# ...

# %%
data2
# Out:
#     Unnamed: 0       Unnamed: 1   CHWR   CHWS   Flow  Load
# 0        BTU-1  2/17/2017 23:55  21.80  18.69   96.0  22.0
# 1        BTU-2  2/17/2017 23:55  23.35  18.79   86.1  29.0
# 2        BTU-1  2/17/2017 23:50  22.83  19.57   93.5  22.5
# 3        BTU-2  2/17/2017 23:50  23.32  19.45   81.5  23.2
# 4        BTU-1  2/17/2017 23:45  22.79  19.40   98.0  24.5
# 5        BTU-2  2/17/2017 23:45  22.97  19.39   85.3  22.5
# 6        BTU-1  2/17/2017 23:40  21.51  19.45  100.8  15.3
# 7        BTU-2  2/17/2017 23:40  22.50  19.51   86.1  19.0
# 8        BTU-1  2/17/2017 23:35  22.54  19.04  134.5  34.7
# 9        BTU-2  2/17/2017 23:35  23.43  18.69  115.7  40.4
# 10       BTU-1  2/17/2017 23:30  22.74  19.45    NaN  22.9
# 11       BTU-2  2/17/2017 23:30  23.45  19.60   82.8  23.5
# 12       BTU-1  2/17/2017 23:25  22.60  19.77   94.2  19.6
# 13       BTU-2  2/17/2017 23:25  23.07  19.75   82.3  20.1
# 14       BTU-1  2/17/2017 23:20  22.28  18.86   93.8  23.6
# ...

# %%
#pd.set_option('display.max_rows',20)

# %%
data2
# Out:
#     Unnamed: 0       Unnamed: 1   CHWR   CHWS   Flow  Load
# 0        BTU-1  2/17/2017 23:55  21.80  18.69   96.0  22.0
# 1        BTU-2  2/17/2017 23:55  23.35  18.79   86.1  29.0
# 2        BTU-1  2/17/2017 23:50  22.83  19.57   93.5  22.5
# 3        BTU-2  2/17/2017 23:50  23.32  19.45   81.5  23.2
# 4        BTU-1  2/17/2017 23:45  22.79  19.40   98.0  24.5
# ..         ...              ...    ...    ...    ...   ...
# 569      BTU-2   2/17/2017 0:10  22.64  18.75   94.9  27.2
# 570      BTU-1   2/17/2017 0:05  22.10  18.79  112.4  27.4
# 571      BTU-2   2/17/2017 0:05  22.62  18.79   95.7  27.0
# 572      BTU-1   2/17/2017 0:00  21.97  18.79  111.2  26.0
# 573      BTU-2   2/17/2017 0:00  22.70  18.73   94.9  27.8
#
# [574 rows x 6 columns]

# %%
data1.describe()
# Out:
#              CHWR        CHWS        Flow        Load
# count  565.000000  566.000000  565.000000  565.000000
# mean    22.347522   18.932615  101.822124   25.324956
# std      0.647804    0.493988   12.438191    3.156783
# min     21.000000   17.270000   81.500000    8.100000
# 25%     21.810000   18.490000   94.300000   24.000000
# 50%     22.310000   18.910000   99.300000   25.500000
# 75%     22.810000   19.240000  111.700000   27.000000
# max     23.940000   21.010000  136.000000   40.400000

# %%
# data2.isnull()
# data2.dropna()

data2.notnull()
# Out:
#      Unnamed: 0  Unnamed: 1  CHWR  CHWS  Flow  Load
# 0          True        True  True  True  True  True
# 1          True        True  True  True  True  True
# 2          True        True  True  True  True  True
# 3          True        True  True  True  True  True
# 4          True        True  True  True  True  True
# ..          ...         ...   ...   ...   ...   ...
# 569        True        True  True  True  True  True
# 570        True        True  True  True  True  True
# 571        True        True  True  True  True  True
# 572        True        True  True  True  True  True
# 573        True        True  True  True  True  True
#
# [574 rows x 6 columns]

# %%
#data1.isnull()

# %% [markdown]
# ###### Removing the null value:

# %%
pd.set_option('display.max_rows',600)
cleaned_data=data2.dropna()
cleaned_data

# rempves entire row with nan value in any columnd
# even a 'thresh' argument can be supplied to select only fist few nan to drop as : > data1.dropna(thresh=3)
# data1.dropna(how='all') > This will remove only those rows whihc have all entries nan
# data1.dropna(axis=1,how ='all') >  This will remove onlty those column which have all entries nan
# Out:
#     Unnamed: 0       Unnamed: 1   CHWR   CHWS   Flow  Load
# 0        BTU-1  2/17/2017 23:55  21.80  18.69   96.0  22.0
# 1        BTU-2  2/17/2017 23:55  23.35  18.79   86.1  29.0
# 2        BTU-1  2/17/2017 23:50  22.83  19.57   93.5  22.5
# 3        BTU-2  2/17/2017 23:50  23.32  19.45   81.5  23.2
# 4        BTU-1  2/17/2017 23:45  22.79  19.40   98.0  24.5
# 5        BTU-2  2/17/2017 23:45  22.97  19.39   85.3  22.5
# 6        BTU-1  2/17/2017 23:40  21.51  19.45  100.8  15.3
# 7        BTU-2  2/17/2017 23:40  22.50  19.51   86.1  19.0
# 8        BTU-1  2/17/2017 23:35  22.54  19.04  134.5  34.7
# 9        BTU-2  2/17/2017 23:35  23.43  18.69  115.7  40.4
# 11       BTU-2  2/17/2017 23:30  23.45  19.60   82.8  23.5
# 12       BTU-1  2/17/2017 23:25  22.60  19.77   94.2  19.6
# 13       BTU-2  2/17/2017 23:25  23.07  19.75   82.3  20.1
# 14       BTU-1  2/17/2017 23:20  22.28  18.86   93.8  23.6
# 15       BTU-2  2/17/2017 23:20  23.19  19.00   82.0  25.3
# ...

# %% [markdown]
# ###### Filling the missing/NaN data

# %%
# filling nan with zero : > data1.fillna(0)
#Diffrent columns can be filled with different value.
data2
# Out:
#     Unnamed: 0       Unnamed: 1   CHWR   CHWS   Flow  Load
# 0        BTU-1  2/17/2017 23:55  21.80  18.69   96.0  22.0
# 1        BTU-2  2/17/2017 23:55  23.35  18.79   86.1  29.0
# 2        BTU-1  2/17/2017 23:50  22.83  19.57   93.5  22.5
# 3        BTU-2  2/17/2017 23:50  23.32  19.45   81.5  23.2
# 4        BTU-1  2/17/2017 23:45  22.79  19.40   98.0  24.5
# 5        BTU-2  2/17/2017 23:45  22.97  19.39   85.3  22.5
# 6        BTU-1  2/17/2017 23:40  21.51  19.45  100.8  15.3
# 7        BTU-2  2/17/2017 23:40  22.50  19.51   86.1  19.0
# 8        BTU-1  2/17/2017 23:35  22.54  19.04  134.5  34.7
# 9        BTU-2  2/17/2017 23:35  23.43  18.69  115.7  40.4
# 10       BTU-1  2/17/2017 23:30  22.74  19.45    NaN  22.9
# 11       BTU-2  2/17/2017 23:30  23.45  19.60   82.8  23.5
# 12       BTU-1  2/17/2017 23:25  22.60  19.77   94.2  19.6
# 13       BTU-2  2/17/2017 23:25  23.07  19.75   82.3  20.1
# 14       BTU-1  2/17/2017 23:20  22.28  18.86   93.8  23.6
# ...

# %%
data2.fillna({'CHWR':data2['CHWR'].mean(),'CHWS':11,'Flow':data2['Flow'].mean(),'Load':13})

# Diffrent columns can be filled with different value. Note:fillna creates a differet object.
#To make change in same object pass argument :> data1.fillna({'CHWR':10,'CHWS':11,'Flow':12,'Load':13},inplace=True)
# Out:
#     Unnamed: 0       Unnamed: 1       CHWR   CHWS        Flow  Load
# 0        BTU-1  2/17/2017 23:55  21.800000  18.69   96.000000  22.0
# 1        BTU-2  2/17/2017 23:55  23.350000  18.79   86.100000  29.0
# 2        BTU-1  2/17/2017 23:50  22.830000  19.57   93.500000  22.5
# 3        BTU-2  2/17/2017 23:50  23.320000  19.45   81.500000  23.2
# 4        BTU-1  2/17/2017 23:45  22.790000  19.40   98.000000  24.5
# 5        BTU-2  2/17/2017 23:45  22.970000  19.39   85.300000  22.5
# 6        BTU-1  2/17/2017 23:40  21.510000  19.45  100.800000  15.3
# 7        BTU-2  2/17/2017 23:40  22.500000  19.51   86.100000  19.0
# 8        BTU-1  2/17/2017 23:35  22.540000  19.04  134.500000  34.7
# 9        BTU-2  2/17/2017 23:35  23.430000  18.69  115.700000  40.4
# 10       BTU-1  2/17/2017 23:30  22.740000  19.45  101.822124  22.9
# 11       BTU-2  2/17/2017 23:30  23.450000  19.60   82.800000  23.5
# 12       BTU-1  2/17/2017 23:25  22.600000  19.77   94.200000  19.6
# ...

# %%
data2.mean()
# Out:
# CHWR     22.347522
# CHWS     18.932615
# Flow    101.822124
# Load     25.324956
# dtype: float64

# %%
data2=data2.fillna(data2.mean())
data2
# Out:
#     Unnamed: 0       Unnamed: 1       CHWR       CHWS        Flow       Load
# 0        BTU-1  2/17/2017 23:55  21.800000  18.690000   96.000000  22.000000
# 1        BTU-2  2/17/2017 23:55  23.350000  18.790000   86.100000  29.000000
# 2        BTU-1  2/17/2017 23:50  22.830000  19.570000   93.500000  22.500000
# 3        BTU-2  2/17/2017 23:50  23.320000  19.450000   81.500000  23.200000
# 4        BTU-1  2/17/2017 23:45  22.790000  19.400000   98.000000  24.500000
# 5        BTU-2  2/17/2017 23:45  22.970000  19.390000   85.300000  22.500000
# 6        BTU-1  2/17/2017 23:40  21.510000  19.450000  100.800000  15.300000
# 7        BTU-2  2/17/2017 23:40  22.500000  19.510000   86.100000  19.000000
# 8        BTU-1  2/17/2017 23:35  22.540000  19.040000  134.500000  34.700000
# 9        BTU-2  2/17/2017 23:35  23.430000  18.690000  115.700000  40.400000
# 10       BTU-1  2/17/2017 23:30  22.740000  19.450000  101.822124  22.900000
# ...

# %%
## Arguments for fillna functions:> value , method, axis, inplace, limit

# %% [markdown]
# ##### Removing duplicates

# %%
dup_data=pd.DataFrame({'apple':[3,5,1,2,2],'mango':[2,7,4,5,5] })
dup_data
# Out:
#    apple  mango
# 0      3      2
# 1      5      7
# 2      1      4
# 3      2      5
# 4      2      5

# %%
dup_data['days']=['Mon','Tue','Wed','Thu','Thu'] # Adding a column

dup_data.reindex(columns=['days','apple','mango']) # rearranging the columns
# Out:
#   days  apple  mango
# 0  Mon      3      2
# 1  Tue      5      7
# 2  Wed      1      4
# 3  Thu      2      5
# 4  Thu      2      5

# %%
dup_data
# Out:
#    apple  mango days
# 0      3      2  Mon
# 1      5      7  Tue
# 2      1      4  Wed
# 3      2      5  Thu
# 4      2      5  Thu

# %%
dup_data.duplicated() # shows whether there is duplicate data or not
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# dtype: bool

# %%
undup_data=dup_data.drop_duplicates()
undup_data
# Out:
#    apple  mango days
# 0      3      2  Mon
# 1      5      7  Tue
# 2      1      4  Wed
# 3      2      5  Thu

# %%
dup_data
# Out:
#    apple  mango days
# 0      3      2  Mon
# 1      5      7  Tue
# 2      1      4  Wed
# 3      2      5  Thu
# 4      2      5  Thu

# %%
und_data=dup_data.drop_duplicates(['days'])
# If we want to filter duplicates based on only columns then :
und_data
# Out:
#    apple  mango days
# 0      3      2  Mon
# 1      5      7  Tue
# 2      1      4  Wed
# 3      2      5  Thu

# %%
# drop_duplicates by default keep the first and removes the duplicatd data 
# after that.
# Passing keep='last' will preserve the last one

und_daata=dup_data.drop_duplicates(keep='last')
und_daata
# Out:
#    apple  mango days
# 0      3      2  Mon
# 1      5      7  Tue
# 2      1      4  Wed
# 4      2      5  Thu

# %% [markdown]
# #### Replacing Values

# %%
und_daata.replace([1,2],10)     # all the 1 and 2 replaced by 10
# Out:
#    apple  mango days
# 0      3     10  Mon
# 1      5      7  Tue
# 2     10      4  Wed
# 4     10      5  Thu

# %%
und_daata.replace([1,2],[10,0.1])
# Out:
#    apple  mango days
# 0    3.0    0.1  Mon
# 1    5.0    7.0  Tue
# 2   10.0    4.0  Wed
# 4    0.1    5.0  Thu

# %%
# Even a dictionary can be passed: in .replace()
und_daata.replace({1:10,2:20,3:30,5:50,4:40,7:70})
# Out:
#    apple  mango days
# 0     30     20  Mon
# 1     50     70  Tue
# 2     10     40  Wed
# 4     20     50  Thu

# %%
## Revisting the data used intitially
data
# Out:
#     Device Name             Date  Temperature (DegC)  Unnamed: 3  \
# 1         BTU-1  2/17/2017 23:55               21.80       18.69
# 2         BTU-2  2/17/2017 23:55               23.35       18.79
# 3         BTU-1  2/17/2017 23:50               22.83       19.57
# 4         BTU-2  2/17/2017 23:50               23.32       19.45
# 5         BTU-1  2/17/2017 23:45               22.79       19.40
# 6         BTU-2  2/17/2017 23:45               22.97       19.39
# 7         BTU-1  2/17/2017 23:40               21.51       19.45
# 8         BTU-2  2/17/2017 23:40               22.50       19.51
# 9         BTU-1  2/17/2017 23:35               22.54       19.04
# 10        BTU-2  2/17/2017 23:35               23.43       18.69
# 11        BTU-1  2/17/2017 23:30               22.74       19.45
# 12        BTU-2  2/17/2017 23:30               23.45       19.60
# 13        BTU-1  2/17/2017 23:25               22.60       19.77
# ...

# %%
data.replace('--',np.nan) # This simply replace all the '--' with NaN.So simple
# Out:
#     Device Name             Date  Temperature (DegC)  Unnamed: 3  \
# 1         BTU-1  2/17/2017 23:55               21.80       18.69
# 2         BTU-2  2/17/2017 23:55               23.35       18.79
# 3         BTU-1  2/17/2017 23:50               22.83       19.57
# 4         BTU-2  2/17/2017 23:50               23.32       19.45
# 5         BTU-1  2/17/2017 23:45               22.79       19.40
# 6         BTU-2  2/17/2017 23:45               22.97       19.39
# 7         BTU-1  2/17/2017 23:40               21.51       19.45
# 8         BTU-2  2/17/2017 23:40               22.50       19.51
# 9         BTU-1  2/17/2017 23:35               22.54       19.04
# 10        BTU-2  2/17/2017 23:35               23.43       18.69
# 11        BTU-1  2/17/2017 23:30               22.74       19.45
# 12        BTU-2  2/17/2017 23:30               23.45       19.60
# 13        BTU-1  2/17/2017 23:25               22.60       19.77
# ...

# %% [markdown]
# ##### Renaming index

# %%
data1.head(2)
# Out:
#   Unnamed: 0       Unnamed: 1   CHWR   CHWS  Flow  Load
# 0      BTU-1  2/17/2017 23:55  21.80  18.69  96.0  22.0
# 1      BTU-2  2/17/2017 23:55  23.35  18.79  86.1  29.0

# %%
data1.rename(columns={'Unnamed: 0':'BTU','Unnamed: 1':'Date'},inplace=True) # Thsi doesn't change the actual data.
# to change actual data Paas - inplace  as .:> data.rename( ......,inplace=True)
# Similarly index can also be renamed.

# %% [markdown]
# ##### Discretization and Binning

# %%
# Revisiting data1
data1
# Out:
#        BTU             Date   CHWR   CHWS   Flow  Load
# 0    BTU-1  2/17/2017 23:55  21.80  18.69   96.0  22.0
# 1    BTU-2  2/17/2017 23:55  23.35  18.79   86.1  29.0
# 2    BTU-1  2/17/2017 23:50  22.83  19.57   93.5  22.5
# 3    BTU-2  2/17/2017 23:50  23.32  19.45   81.5  23.2
# 4    BTU-1  2/17/2017 23:45  22.79  19.40   98.0  24.5
# 5    BTU-2  2/17/2017 23:45  22.97  19.39   85.3  22.5
# 6    BTU-1  2/17/2017 23:40  21.51  19.45  100.8  15.3
# 7    BTU-2  2/17/2017 23:40  22.50  19.51   86.1  19.0
# 8    BTU-1  2/17/2017 23:35  22.54  19.04  134.5  34.7
# 9    BTU-2  2/17/2017 23:35  23.43  18.69  115.7  40.4
# 10   BTU-1  2/17/2017 23:30  22.74  19.45    NaN  22.9
# 11   BTU-2  2/17/2017 23:30  23.45  19.60   82.8  23.5
# 12   BTU-1  2/17/2017 23:25  22.60  19.77   94.2  19.6
# 13   BTU-2  2/17/2017 23:25  23.07  19.75   82.3  20.1
# 14   BTU-1  2/17/2017 23:20  22.28  18.86   93.8  23.6
# 15   BTU-2  2/17/2017 23:20  23.19  19.00   82.0  25.3
# ...

# %%
 cats=pd.cut(data1['Load'],3)# here first argument the data ,second is the number of bins
    # we can specify our on bins as list :   cats=pd.cut(data1['Load'],[8,19,30,41])

# %%
cats
# Out:
# 0      (18.867, 29.633]
# 1      (18.867, 29.633]
# 2      (18.867, 29.633]
# 3      (18.867, 29.633]
# 4      (18.867, 29.633]
# 5      (18.867, 29.633]
# 6       (8.068, 18.867]
# 7      (18.867, 29.633]
# 8        (29.633, 40.4]
# 9        (29.633, 40.4]
# 10     (18.867, 29.633]
# 11     (18.867, 29.633]
# 12     (18.867, 29.633]
# 13     (18.867, 29.633]
# 14     (18.867, 29.633]
# 15     (18.867, 29.633]
# 16     (18.867, 29.633]
# 17     (18.867, 29.633]
# 18     (18.867, 29.633]
# 19     (18.867, 29.633]
# 20     (18.867, 29.633]
# 21                  NaN
# 22     (18.867, 29.633]
# 23     (18.867, 29.633]
# 24     (18.867, 29.633]
# 25     (18.867, 29.633]
# 26     (18.867, 29.633]
# 27     (18.867, 29.633]
# 28     (18.867, 29.633]
# 29     (18.867, 29.633]
# 30      (8.068, 18.867]
# 31      (8.068, 18.867]
# 32     (18.867, 29.633]
# 33     (18.867, 29.633]
# 34     (18.867, 29.633]
# 35     (18.867, 29.633]
# 36     (18.867, 29.633]
# 37     (18.867, 29.633]
# ...

# %%
pd.value_counts(cats)
# Out:
# (18.867, 29.633]    524
# (29.633, 40.4]       25
# (8.068, 18.867]      16
# Name: Load, dtype: int64

# %%
cats1=pd.cut(data1['Load'],[8,19,30,41])
pd.value_counts(cats1)
# Out:
# (19, 30]    524
# (30, 41]     22
# (8, 19]      19
# Name: Load, dtype: int64

# %%
# We can also name individual group
bins=[8,19,30,41]
group_name=['Low load','Medium Load','High Load']
cats1=pd.cut(data1['Load'],bins,labels=group_name)
pd.value_counts(cats1)
# Out:
# Medium Load    524
# High Load       22
# Low load        19
# Name: Load, dtype: int64

# %%
pd.qcut(data1['Load'],4) # This qcut bins the data based on Sample quantiles 
# we can pass : precision= any number , to restrict number of digit after decimal if data have many decimal values
# Out:
# 0      (8.099, 24.0]
# 1       (27.0, 40.4]
# 2      (8.099, 24.0]
# 3      (8.099, 24.0]
# 4       (24.0, 25.5]
# 5      (8.099, 24.0]
# 6      (8.099, 24.0]
# 7      (8.099, 24.0]
# 8       (27.0, 40.4]
# 9       (27.0, 40.4]
# 10     (8.099, 24.0]
# 11     (8.099, 24.0]
# 12     (8.099, 24.0]
# 13     (8.099, 24.0]
# 14     (8.099, 24.0]
# 15      (24.0, 25.5]
# 16     (8.099, 24.0]
# 17     (8.099, 24.0]
# 18      (27.0, 40.4]
# 19      (27.0, 40.4]
# 20     (8.099, 24.0]
# 21               NaN
# 22     (8.099, 24.0]
# 23     (8.099, 24.0]
# 24     (8.099, 24.0]
# 25      (24.0, 25.5]
# 26      (24.0, 25.5]
# 27      (27.0, 40.4]
# 28      (24.0, 25.5]
# 29     (8.099, 24.0]
# 30     (8.099, 24.0]
# 31     (8.099, 24.0]
# 32     (8.099, 24.0]
# 33     (8.099, 24.0]
# 34      (27.0, 40.4]
# 35      (27.0, 40.4]
# 36     (8.099, 24.0]
# 37     (8.099, 24.0]
# 38     (8.099, 24.0]
# 39     (8.099, 24.0]
# 40     (8.099, 24.0]
# 41      (25.5, 27.0]
# 42      (24.0, 25.5]
# ...
